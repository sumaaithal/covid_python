# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#dropped literacy rate,poverty head, handwashing facilities, test_units, Increase in poverty gap and  since it had 60% above null values

# %%
#def imputation(df):
#    df_cols = [col for col in df.columns]
#    for col in df_cols[2:]:
#        if df[col].isnull().any():
#            df[col].fillna(df[col].mean(),inplace=True)
#    return df

# %%
#imputation(df_covid)

# %%
df = pd.read_csv("C:/Users/USER/Desktop/internship/final_covid_dataset.csv",index_col=0)

# %%
df.head()
# Out:
#            Country Name Country codes  Total_Cases  New_Cases  Total_Deaths  \
# 0           Afghanistan           AFG      44771.0      252.0        1695.0
# 1  United Arab Emirates           ARE     158990.0     1205.0         552.0
# 2             Argentina           ARG    1370350.0     4181.0       37002.0
# 3               Armenia           ARM     126709.0      485.0        1976.0
# 4             Australia           AUS      27821.0       14.0         907.0
#
#    New_Deaths  Total_Cases_Per_Million  New_Cases_Per_Million  \
# 0         8.0                   1150.0                   6.47
# 1         4.0                  16075.0                 121.84
# 2       100.0                  30320.0                  92.51
# 3        24.0                  42760.0                 163.67
# 4         0.0                   1091.0                   0.55
#
#    Total_Deaths_Per_Million  New_Deaths_Per_Million  ...  \
# 0                     43.54                    0.21  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 0 to 108
# Data columns (total 54 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Country Name                                          109 non-null    object
#  1   Country codes                                         109 non-null    object
#  2   Total_Cases                                           109 non-null    float64
#  3   New_Cases                                             109 non-null    float64
#  4   Total_Deaths                                          109 non-null    float64
#  5   New_Deaths                                            109 non-null    float64
#  6   Total_Cases_Per_Million                               109 non-null    float64
#  7   New_Cases_Per_Million                                 109 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Total_Cases      New_Cases   Total_Deaths  New_Deaths  \
# count  1.090000e+02     109.000000     109.000000  109.000000
# mean   5.316466e+05    4474.611111   12627.750000   58.629630
# std    1.575663e+06   16115.222796   34092.383541  130.396801
# min    1.306000e+03       0.000000      25.000000    0.000000
# 25%    3.033300e+04      48.000000     328.000000    1.000000
# 50%    1.211200e+05     850.000000    1657.000000    6.000000
# 75%    4.186450e+05    2756.000000    8879.000000   49.000000
# max    1.224691e+07  157471.000000  256782.000000  883.000000
#
#        Total_Cases_Per_Million  New_Cases_Per_Million  \
# count               109.000000             109.000000
# mean              13752.796296             141.027778
# std               12908.402706             213.060536
# min                  13.000000               0.000000
# 25%                1637.000000               3.430000
# 50%               10522.000000              48.940000
# ...

# %%
df.isnull().sum()
# Out:
# Country Name                                            0
# Country codes                                           0
# Total_Cases                                             0
# New_Cases                                               0
# Total_Deaths                                            0
# New_Deaths                                              0
# Total_Cases_Per_Million                                 0
# New_Cases_Per_Million                                   0
# Total_Deaths_Per_Million                                0
# New_Deaths_Per_Million                                  0
# New_Deaths_Smoothed_Per_Million                         0
# Total_Tests                                             0
# New_Tests                                               0
# Total_Tests_Per_Thousand                                0
# New_Tests_Per_Thousand                                  0
# Tests_Per_Case                                          0
# ...

# %%
df.corr()
# Out:
#                                                     Total_Cases  New_Cases  \
# Total_Cases                                            1.000000   0.886308
# New_Cases                                              0.886308   1.000000
# Total_Deaths                                           0.943293   0.850087
# New_Deaths                                             0.793240   0.839786
# Total_Cases_Per_Million                                0.230721   0.219760
# New_Cases_Per_Million                                  0.096148   0.227963
# Total_Deaths_Per_Million                               0.325085   0.281457
# New_Deaths_Per_Million                                 0.031958   0.120071
# New_Deaths_Smoothed_Per_Million                        0.091036   0.149321
# Total_Tests                                            0.659551   0.659371
# New_Tests                                              0.775439   0.628834
# ...

# %%
plt.figure(figsize=(30,28))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
